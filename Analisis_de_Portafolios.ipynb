# %%
#Importar las librerias

import numpy as np
import pandas as pd

import datetime
import matplotlib.pyplot as plt

from pandas.plotting import scatter_matrix

# %%
import yfinance as yf

# %%
# !pip install yfinance

# %% [markdown]
# ## Vamos a comparar estdisticamente una lista de tickers.

# %%
# Vamos a descargar tres tickers

fecha_inicial = "2020-12-01"
fecha_final = "2023-10-04"

# %%
femsa = yf.download("FEMSAUBD.MX", fecha_inicial, fecha_final)

tsla = yf.download("TSLA", fecha_inicial, fecha_final)

Cuervo = yf.download("CUERVO.MX", fecha_inicial, fecha_final)

ac = yf.download("AC.MX", fecha_inicial, fecha_final)

alsea = yf.download("ALSEA.MX", fecha_inicial, fecha_final)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
tickers = ["FEMSAUBD.MX", "TSLA", "CUERVO.MX", "AC.MX", "ALSEA.MX" ]

datos = yf.download(tickers, fecha_inicial, fecha_final)["Close"]
datos
# Out:
# [*********************100%%**********************]  5 of 5 completed
#                  AC.MX   ALSEA.MX  CUERVO.MX  FEMSAUBD.MX        TSLA
# Date
# 2020-12-01  101.360001  27.709999  47.029999   152.229996  194.919998
# 2020-12-02  104.800003  27.740000  47.889999   155.089996  189.606674
# 2020-12-03  104.260002  28.440001  47.639999   151.460007  197.793335
# 2020-12-04  102.910004  28.610001  47.630001   151.360001  199.679993
# 2020-12-07  104.360001  28.590000  48.070000   150.520004  213.919998
# ...                ...        ...        ...          ...         ...
# 2023-09-27  157.289993  63.340000  43.259998   189.380005  240.500000
# 2023-09-28  158.050003  63.419998  42.560001   189.089996  246.380005
# 2023-09-29  158.770004  63.599998  41.619999   189.979996  250.220001
# 2023-10-02  160.149994  62.990002  41.590000   195.759995  251.600006
# 2023-10-03  157.949997  63.360001  40.930000   194.940002  246.529999
#
# [736 rows x 5 columns]

# %%
varianza = datos.std()**2
varianza
# Out:
# AC.MX           575.453119
# ALSEA.MX         82.782061
# CUERVO.MX        13.505030
# FEMSAUBD.MX     309.709890
# TSLA           3263.374199
# dtype: float64

# %%
varianza = datos.var()
varianza
# Out:
# AC.MX           575.453119
# ALSEA.MX         82.782061
# CUERVO.MX        13.505030
# FEMSAUBD.MX     309.709890
# TSLA           3263.374199
# dtype: float64

# %%
rendimientos = datos.pct_change
rendimientos
# Out:
# <bound method NDFrame.pct_change of                  AC.MX   ALSEA.MX  CUERVO.MX  FEMSAUBD.MX        TSLA
# Date
# 2020-12-01  101.360001  27.709999  47.029999   152.229996  194.919998
# 2020-12-02  104.800003  27.740000  47.889999   155.089996  189.606674
# 2020-12-03  104.260002  28.440001  47.639999   151.460007  197.793335
# 2020-12-04  102.910004  28.610001  47.630001   151.360001  199.679993
# 2020-12-07  104.360001  28.590000  48.070000   150.520004  213.919998
# ...                ...        ...        ...          ...         ...
# 2023-09-27  157.289993  63.340000  43.259998   189.380005  240.500000
# 2023-09-28  158.050003  63.419998  42.560001   189.089996  246.380005
# 2023-09-29  158.770004  63.599998  41.619999   189.979996  250.220001
# 2023-10-02  160.149994  62.990002  41.590000   195.759995  251.600006
# 2023-10-03  157.949997  63.360001  40.930000   194.940002  246.529999
#
# [736 rows x 5 columns]>

# %%
datos.cov()
# Out:
#                   AC.MX    ALSEA.MX  CUERVO.MX  FEMSAUBD.MX         TSLA
# AC.MX        575.453119  161.969329 -46.154945   145.170941  -384.656037
# ALSEA.MX     161.969329   82.782061  -7.206751   104.368318    50.572163
# CUERVO.MX    -46.154945   -7.206751  13.505030    10.958985    51.567743
# FEMSAUBD.MX  145.170941  104.368318  10.958985   309.709890   -89.475908
# TSLA        -384.656037   50.572163  51.567743   -89.475908  3263.374199
