# %%
Sebas = {"Sebas": [8.4,1.80,20,1]}

# %%
type (Sebas)
# Out:
# dict

# %%
POOP_UP = {"Emilio": [8.3,1.38,20,1],
           "Manuel": [9.2,1.77,21,1],
           "Farca ": [9.0,1.72,19,0]}

# %%
print(POOP_UP)
# Out:
# {'Emilio': [8.3, 1.38, 20, 1], 'Manuel': [9.2, 1.77, 21, 1], 'Farca ': [9.0, 1.72, 19, 0]}

# %%
# Importamos al modulo Pandas

import pandas as pd

# %%
Alumnos = pd.DataFrame(POOP_UP)

# %%
Alumnos
# Out:
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(Alumnos, *['Emilio'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(Alumnos, *['Manuel'], **{})
# chart
# import numpy as np
# ...

# %%
type (Alumnos)
# Out:
# pandas.core.frame.DataFrame

# %%
Alumnos.ndim #Dimension como objetos en Python
# Out:
# 2

# %%
Alumnos["Emilio"]
# Out:
# 0     8.30
# 1     1.38
# 2    20.00
# 3     1.00
# Name: Emilio, dtype: float64

# %%
type ("Emilio")
# Out:
# str

# %%
Alumnos.iloc[0]
# Out:
# Emilio    8.3
# Manuel    9.2
# Farca     9.0
# Name: 0, dtype: float64

# %%
Alumnos [{"Emilio", "Manuel"}]
# Out:
# <ipython-input-22-affaf7d5fe2a>:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   Alumnos [{"Emilio", "Manuel"}]
#    Emilio  Manuel
# 0    8.30    9.20
# 1    1.38    1.77
# 2   20.00   21.00
# 3    1.00    1.00

# %%
Alumnos.iloc[0:2] #rebana la base de datos del primer renglon

                  # al segundo
# Out:
#    Emilio  Manuel  Farca
# 0    8.30    9.20    9.00
# 1    1.38    1.77    1.72
