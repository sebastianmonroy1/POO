# %%
#Tarea 1.2
#Emilio MIlanesi y Sebastián Monroy


from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

file_path = "/content/drive/MyDrive/daily_returns.csv"
df = pd.read_csv(file_path)

# %%
df.set_index('Unnamed: 0', inplace=True)

# %%
mean = df.mean()
variance = df.var()

# %%
def transform_column(column):
    mean = column.mean()
    std = column.std()
    return (column - mean) / std

# %%
df_transformed = df.apply(transform_column)

# %%
import matplotlib.pyplot as plt

df['AAPL'].plot()
plt.title('Serie de Tiempo de AAPL')
plt.xlabel('Fecha')
plt.ylabel('Valor')
plt.show()

# %%
df_transformed.describe()
# Out:
#                AAPL           JPM           WMT           TGT          MSFT  \
# count  4.692000e+03  4.692000e+03  4.692000e+03  4.692000e+03  4.692000e+03
# mean   1.514371e-18  3.028741e-18 -1.892963e-17  2.271556e-18 -7.571854e-18
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -2.010729e+01 -8.343671e+00 -6.746604e+00 -6.174682e+00 -8.111661e+00
# 25%   -4.566429e-01 -3.859255e-01 -4.741910e-01 -4.668957e-01 -4.466574e-01
# 50%   -1.787023e-02 -1.913574e-02  1.381302e-03 -9.207591e-03 -1.647219e-02
# 75%    4.617495e-01  3.707853e-01  4.464293e-01  4.425990e-01  4.365179e-01
# max    5.330500e+00  1.006020e+01  7.311059e+00  8.747919e+00  1.013780e+01
#
#                AMGN
# count  4.692000e+03
# mean  -8.329039e-18
# std    1.000000e+00
# min   -6.624312e+00
# 25%   -4.695241e-01
# 50%   -2.254873e-02
# 75%    4.584042e-01
# max    7.410904e+00

# %% [markdown]
# PARTE B

# %%
import math

def circulo(radio):
  xc= math.pi * (radio ** 2)
  return xc

# %%
def rectangulo(base, altura):
  xr=base*altura
  return xr

# %%
import math
def raiz(numero):
  xsqrt=math.sqrt(numero)
  return xsqrt

# %%
raiz(9)
# Out:
# 3.0

# %%
rectangulo(5,4)
# Out:
# 20

# %%
circulo(2)
# Out:
# 12.566370614359172

# %%
import random


lista = [random.randint(0, 100) for _ in range(20)]


print(lista)
# Out:
# [77, 88, 15, 39, 54, 25, 29, 1, 41, 21, 39, 8, 25, 4, 71, 35, 4, 60, 38, 80]

# %%
raices = [raiz(numero) for numero in lista]
raices
# Out:
# [8.774964387392123,
#  9.38083151964686,
#  3.872983346207417,
#  6.244997998398398,
#  7.3484692283495345,
#  5.0,
#  5.385164807134504,
#  1.0,
#  6.4031242374328485,
#  4.58257569495584,
#  6.244997998398398,
#  2.8284271247461903,
#  5.0,
#  2.0,
#  8.426149773176359,
#  5.916079783099616,
#  2.0,
#  7.745966692414834,
#  6.164414002968976,
#  8.94427190999916]

# %%
enterossqrt = {
    numero
    for numero in lista
    if math.sqrt(numero).is_integer()
}
print(enterossqrt)
# Out:
# {25, 4, 1}
